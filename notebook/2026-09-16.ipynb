# %%
import numpy as np
import pandas as pd
import statsmodels as sm

# %%
df_cdata = pd.read_excel(
    "/Users/nguyenthang/Repositories/econ-consumption/data/cdata.xls",
    engine="xlrd",
    skiprows=3,
)

df_rdata = pd.read_excel(
    "/Users/nguyenthang/Repositories/econ-consumption/data/rdata.xls",
    engine="xlrd",
    skiprows=3,
)
